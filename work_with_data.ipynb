# %%
import pandas as pd
data = pd.read_csv("CarPrice.csv")

# im reading the Pandas Doc to get familiar with it

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
type(data)
# will according to Pandas Doc : 
# A DataFrame is a 2-dimensional data structure that can store data of different types (including characters,
# # integers, floating point values, categorical data and more) in columns. It is similar to a spreadsheet, a SQL table
# Out:
# pandas.core.frame.DataFrame

# %%
# each table in dataframe is a series  
data["CarName"]
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %%
#one more time 
data["stroke"]

#A pandas Series has no column labels, as it is just a single column of a DataFrame. A Series does have row labels.
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: float64

# %%
# will now its a good time to get detail and info of each series 

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
# list find the price of most expensive car in our data

data["price"].max()
# Out:
# 45400.0

# %%
# now lets find a car with minimum engine size 

data["enginesize"].min()
# Out:
# 61

# %%
# lets get all  type of calculations in a series

data["price"].describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
# and now on a dataframe 
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# what if we run describe on carbody or fueltype series that have string type of values  lets find out 

data["carbody"].describe()
# Out:
# count       205
# unique        5
# top       sedan
# freq         96
# Name: carbody, dtype: object

# %%
# i can even do this 
data.describe(include=["object"])
# Out:
#               CarName fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
# and for a full detail report 

data.describe(include="all")
# Out:
#             car_ID   symboling        CarName fueltype aspiration doornumber  \
# count   205.000000  205.000000            205      205        205        205
# unique         NaN         NaN            147        2          2          2
# top            NaN         NaN  toyota corona      gas        std       four
# freq           NaN         NaN              6      185        168        115
# mean    103.000000    0.834146            NaN      NaN        NaN        NaN
# std      59.322565    1.245307            NaN      NaN        NaN        NaN
# min       1.000000   -2.000000            NaN      NaN        NaN        NaN
# 25%      52.000000    0.000000            NaN      NaN        NaN        NaN
# 50%     103.000000    1.000000            NaN      NaN        NaN        NaN
# 75%     154.000000    2.000000            NaN      NaN        NaN        NaN
# max     205.000000    3.000000            NaN      NaN        NaN        NaN
#
# ...

# %%
# you can find the data type of all column by info as i mentioned but you can use this attribute too
data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
# DataFrame.shape is an attribute of a pandas Series and DataFrame
# containing the number of rows and columns: (nrows, ncolumns).
# A pandas Series is 1-dimensional and only the number of rows is returned.

data.shape
# Out:
# (205, 26)

# %%
data["CarName"].shape
# Out:
# (205,)

# %%
# now lets create a datefreame only with name and price
name_price_data = data[["CarName","price"]]
name_price_data
# Out:
#                       CarName    price
# 0          alfa-romero giulia  13495.0
# 1         alfa-romero stelvio  16500.0
# 2    alfa-romero Quadrifoglio  16500.0
# 3                 audi 100 ls  13950.0
# 4                  audi 100ls  17450.0
# ..                        ...      ...
# 200           volvo 145e (sw)  16845.0
# 201               volvo 144ea  19045.0
# 202               volvo 244dl  21485.0
# 203                 volvo 246  22470.0
# 204               volvo 264gl  22625.0
#
# [205 rows x 2 columns]

# %%
# now lets filter our rows shell we?
#  i need list of cars  with horse power between 70 to 100 and doornumber 2

my_selection = data[(data["horsepower"] > 70) & (data["horsepower"]< 100) & (data["doornumber"] == "two") ]
my_selection
# Out:
#      car_ID  symboling                       CarName fueltype aspiration  \
# 31       32          2              honda civic cvcc      gas        std
# 33       34          1             honda accord cvcc      gas        std
# 34       35          1              honda civic cvcc      gas        std
# 37       38          0                  honda accord      gas        std
# 38       39          0              honda civic 1300      gas        std
# 46       47          2                  isuzu D-Max       gas        std
# 59       60          1                     mazda 626      gas        std
# 61       62          1              mazda glc custom      gas        std
# 81       82          3                 mitsubishi g4      gas        std
# 131     132          2                 renault 5 gtl      gas        std
# 139     140          2                     subaru dl      gas        std
# 140     141          2                     subaru dl      gas        std
# ...

# %%
my_selection = my_selection[my_selection["symboling"].isin([2,1])]
my_selection
# Out:
#      car_ID  symboling                       CarName fueltype aspiration  \
# 31       32          2              honda civic cvcc      gas        std
# 33       34          1             honda accord cvcc      gas        std
# 34       35          1              honda civic cvcc      gas        std
# 46       47          2                  isuzu D-Max       gas        std
# 59       60          1                     mazda 626      gas        std
# 61       62          1              mazda glc custom      gas        std
# 131     132          2                 renault 5 gtl      gas        std
# 139     140          2                     subaru dl      gas        std
# 140     141          2                     subaru dl      gas        std
# 183     184          2  volkswagen 1131 deluxe sedan      gas        std
#
#     doornumber    carbody drivewheel enginelocation  wheelbase  ...  \
# 31         two  hatchback        fwd          front       86.6  ...
# ...

# %%
# using loc and iloc 
name_and_price_of_two_doors = data.loc[data["doornumber"]=="two",["CarName","price"]]
name_and_price_of_two_doors
# Out:
#                           CarName      price
# 0              alfa-romero giulia  13495.000
# 1             alfa-romero stelvio  16500.000
# 2        alfa-romero Quadrifoglio  16500.000
# 5                        audi fox  15250.000
# 9             audi 5000s (diesel)  17859.167
# ..                            ...        ...
# 179                 toyota corona  15998.000
# 182              vokswagen rabbit   7775.000
# 183  volkswagen 1131 deluxe sedan   7975.000
# 189                     vw dasher  11595.000
# 190                     vw rabbit   9980.000
#
# [90 rows x 2 columns]

# %%
# add now name  and price my_selection

data.loc[(data["horsepower"] > 70) & (data["horsepower"]< 100) & (data["doornumber"] == "two") & (data["symboling"].isin([2,1])),["CarName","price"]]
# Out:
#                           CarName    price
# 31               honda civic cvcc   6855.0
# 33              honda accord cvcc   6529.0
# 34               honda civic cvcc   7129.0
# 46                   isuzu D-Max   11048.0
# 59                      mazda 626   8845.0
# 61               mazda glc custom  10595.0
# 131                 renault 5 gtl   9895.0
# 139                     subaru dl   7053.0
# 140                     subaru dl   7603.0
# 183  volkswagen 1131 deluxe sedan   7975.0

# %%
# iloc use index 

data.iloc[100:120,3:7]
# Out:
#     fueltype aspiration doornumber    carbody
# 100      gas        std       four      sedan
# 101      gas        std       four      sedan
# 102      gas        std       four      wagon
# 103      gas        std       four      sedan
# 104      gas        std        two  hatchback
# 105      gas      turbo        two  hatchback
# 106      gas        std        two  hatchback
# 107      gas        std       four      sedan
# 108   diesel      turbo       four      sedan
# 109      gas        std       four      wagon
# 110   diesel      turbo       four      wagon
# 111      gas        std       four      sedan
# 112   diesel      turbo       four      sedan
# 113      gas        std       four      wagon
# 114   diesel      turbo       four      wagon
# 115      gas        std       four      sedan
# 116   diesel      turbo       four      sedan
# 117      gas      turbo       four      sedan
# 118      gas        std        two  hatchback
# ...

# %%
import sys

sys.path.insert(1, "./.venv/lib/python3.8/site-packages")

# %%
# time to create plots 
import matplotlib.pyplot as plt

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data["price"].plot()
# Out:
# <AxesSubplot:>

# %%
data.plot.scatter(x="price", y="enginesize", alpha=0.7)
# Out:
# <AxesSubplot:xlabel='price', ylabel='enginesize'>

# %%
[
    method_name
    for method_name in dir(data.plot)
    if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
# lets create new column by sum enginesise and horsepower and name it power

data["power"] = (data["enginesize"]+ data["horsepower"])

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# and now lets rename it 
data= data.rename(columns={"power":"newPower"})
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# we can also rename using function
data = data.rename(columns=str.lower)
data
# Out:
#      car_id  symboling                   carname fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.agg(
    {
        "price":["min","max","std"],
        "horsepower": ["min", "max"]
    }
)
# Out:
#             price  horsepower
# max  45400.000000       288.0
# min   5118.000000        48.0
# std   7988.852332         NaN

# %%
data[["symboling","price"]].groupby("symboling").mean()
# Out:
#                   price
# symboling
# -2         15781.666667
# -1         17330.681818
#  0         14366.965179
#  1         10037.907407
#  2         10109.281250
#  3         17221.296296

# %%
data.groupby("CarName").max()
# Out:
#                           car_ID  symboling fueltype aspiration doornumber  \
# CarName
# Nissan versa                  90          1      gas        std        two
# alfa-romero Quadrifoglio       3          1      gas        std        two
# alfa-romero giulia             1          3      gas        std        two
# alfa-romero stelvio            2          3      gas        std        two
# audi 100 ls                    4          2      gas        std       four
# ...                          ...        ...      ...        ...        ...
# volvo 246                    204         -1   diesel      turbo       four
# volvo 264gl                  205         -1      gas      turbo       four
# volvo diesel                 200         -1      gas      turbo       four
# vw dasher                    190          3      gas        std        two
# vw rabbit                    191          3      gas        std        two
#
# ...

# %%
data.groupby(["fueltype","symboling"])["price"].mean()
# Out:
# fueltype  symboling
# diesel    -1           23713.600000
#            0           15075.545455
#            1            7099.000000
#            2            8421.666667
# gas       -2           15781.666667
#           -1           15453.352941
#            0           14227.779768
#            1           10093.358491
#            2           10283.862069
#            3           17221.296296
# Name: price, dtype: float64

# %%
data["fueltype"].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
data.groupby("fueltype")["fueltype"].count()
# Both size and count can be used in combination with groupby. 
# Whereas size includes NaN values and just provides the number of rows (size of the table),
# count excludes the missing values. In the value_counts method,
# use the dropna argument to include or exclude the NaN values.
# Out:
# fueltype
# diesel     20
# gas       185
# Name: fueltype, dtype: int64

# %%
# will now its time to sort 
data.sort_values(by="CarName", ascending=False, )
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 190     191          3                 vw rabbit      gas        std
# 189     190          3                 vw dasher      gas        std
# 199     200         -1              volvo diesel      gas      turbo
# 198     199         -2               volvo 264gl      gas      turbo
# 204     205         -1               volvo 264gl      gas      turbo
# ..      ...        ...                       ...      ...        ...
# 3         4          2               audi 100 ls      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 0         1          3        alfa-romero giulia      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 89       90          1              Nissan versa      gas        std
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.sort_values(by=["CarName","carbody"])
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 89       90          1              Nissan versa      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 3         4          2               audi 100 ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 198     199         -2               volvo 264gl      gas      turbo
# 204     205         -1               volvo 264gl      gas      turbo
# 199     200         -1              volvo diesel      gas      turbo
# 189     190          3                 vw dasher      gas        std
# 190     191          3                 vw rabbit      gas        std
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# will if you see the sort is case sensitive  and Pandas dont have anything to fix it but we can use lambda 
data.sort_values(by="CarName", ascending=True, key=lambda col: col.str.lower())
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 198     199         -2               volvo 264gl      gas      turbo
# 204     205         -1               volvo 264gl      gas      turbo
# 199     200         -1              volvo diesel      gas      turbo
# 189     190          3                 vw dasher      gas        std
# 190     191          3                 vw rabbit      gas        std
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# pivot[it remand me ross on Friends]
car_body = data[data["fueltype"] == "gas"]
car_body = car_body.sort_index().groupby(["carbody"]).head(2) # only to of each car body
car_body
# Out:
#     car_ID  symboling                          CarName fueltype aspiration  \
# 0        1          3               alfa-romero giulia      gas        std
# 1        2          3              alfa-romero stelvio      gas        std
# 2        3          1         alfa-romero Quadrifoglio      gas        std
# 3        4          2                      audi 100 ls      gas        std
# 4        5          2                       audi 100ls      gas        std
# 7        8          1                        audi 5000      gas        std
# 9       10          0              audi 5000s (diesel)      gas      turbo
# 28      29         -1                dodge dart custom      gas        std
# 74      75          1  buick regal sport coupe (turbo)      gas        std
# 98      99          2                   nissan clipper      gas        std
#
#    doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0         two  convertible        rwd          front       88.6  ...
# ...

# %%
car_body.pivot(columns="carbody", values="price")
# will obviously that car data is not good sample fro this section 
# read doc -> https://pandas.pydata.org/docs/getting_started/intro_tutorials/07_reshape_table_layout.html
# Out:
# carbody  convertible  hardtop  hatchback    sedan    wagon
# 0            13495.0      NaN        NaN      NaN      NaN
# 1            16500.0      NaN        NaN      NaN      NaN
# 2                NaN      NaN  16500.000      NaN      NaN
# 3                NaN      NaN        NaN  13950.0      NaN
# 4                NaN      NaN        NaN  17450.0      NaN
# 7                NaN      NaN        NaN      NaN  18920.0
# 9                NaN      NaN  17859.167      NaN      NaN
# 28               NaN      NaN        NaN      NaN   8921.0
# 74               NaN  45400.0        NaN      NaN      NaN
# 98               NaN   8249.0        NaN      NaN      NaN

# %%
# okey im gonna skip this one too cause my data dont have ability to do this 
# but it was so help full specially the merge method which is the Join from SQL 
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/08_combine_dataframes.html

# %%
# also we dont have date and time ether so 
# -> https://pandas.pydata.org/docs/getting_started/intro_tutorials/09_timeseries.html

# %%
data["CarName"].str.lower()
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %%
data["CarName"].str.split(" ")
# Out:
# 0            [alfa-romero, giulia]
# 1           [alfa-romero, stelvio]
# 2      [alfa-romero, Quadrifoglio]
# 3                  [audi, 100, ls]
# 4                    [audi, 100ls]
#                   ...
# 200            [volvo, 145e, (sw)]
# 201                 [volvo, 144ea]
# 202                 [volvo, 244dl]
# 203                   [volvo, 246]
# 204                 [volvo, 264gl]
# Name: CarName, Length: 205, dtype: object

# %%
data["company"] = data["CarName"].str.lower().str.split(" ").str.get(0)

# %%
data.groupby(data["company"]).head(2)
# Out:
#      car_ID  symboling                       CarName fueltype aspiration  \
# 0         1          3            alfa-romero giulia      gas        std
# 1         2          3           alfa-romero stelvio      gas        std
# 3         4          2                   audi 100 ls      gas        std
# 4         5          2                    audi 100ls      gas        std
# 10       11          2                      bmw 320i      gas        std
# 11       12          0                      bmw 320i      gas        std
# 18       19          2              chevrolet impala      gas        std
# 19       20          1         chevrolet monte carlo      gas        std
# 21       22          1                 dodge rampage      gas        std
# 22       23          1           dodge challenger se      gas        std
# 30       31          2                   honda civic      gas        std
# 31       32          2              honda civic cvcc      gas        std
# ...

# %%
data["company"].str.contains("dodge")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: company, Length: 205, dtype: bool

# %%
data[data["company"].str.contains("dodge")]
# Out:
#     car_ID  symboling                    CarName fueltype aspiration  \
# 21      22          1              dodge rampage      gas        std
# 22      23          1        dodge challenger se      gas        std
# 23      24          1                 dodge d200      gas      turbo
# 24      25          1          dodge monaco (sw)      gas        std
# 25      26          1         dodge colt hardtop      gas        std
# 26      27          1            dodge colt (sw)      gas        std
# 27      28          1       dodge coronet custom      gas      turbo
# 28      29         -1          dodge dart custom      gas        std
# 29      30          3  dodge coronet custom (sw)      gas      turbo
#
#    doornumber    carbody drivewheel enginelocation  wheelbase  ...  \
# 21        two  hatchback        fwd          front       93.7  ...
# 22        two  hatchback        fwd          front       93.7  ...
# 23        two  hatchback        fwd          front       93.7  ...
# ...

# %%
data[data["price"].eq(data["price"].max())]
#finally the thing that i want in first place :)))
# Out:
#     car_ID  symboling                          CarName fueltype aspiration  \
# 74      75          1  buick regal sport coupe (turbo)      gas        std
#
#    doornumber  carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 74        two  hardtop        rwd          front      112.0  ...        mpfi
#
#     boreratio  stroke  compressionratio horsepower peakrpm  citympg  \
# 74        3.8    3.35               8.0        184    4500       14
#
#    highwaympg    price  company
# 74         16  45400.0    buick
#
# [1 rows x 27 columns]

# %%
data.loc[data["price"].eq(data["price"].max()), "CarName"]
# tis one is cooler
# Out:
# 74    buick regal sport coupe (turbo)
# Name: CarName, dtype: object

# %%
# will end of journey lets go do some prediction
